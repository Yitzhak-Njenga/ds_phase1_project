# %% [markdown]
# # Final Project Submission
#
# Please fill out:
# * Student name: Yitzhak Njenga
# * Student pace:  Part time
# * Scheduled project review date/time:
# * Instructor name: Sam G
# * Blog post URL:

# %%
#importing libraries
import csv
import pandas as pd

# %%
#connect csv file
csv_file_path = 'zippedData/tmdb.movies.csv'

# %%
#printing from row & colums of csv file
with open(csv_file_path) as csvfile:
  reader = csv.DictReader(csvfile)
  #print(next(reader))
  for i in reader:
    print(i)

# %%
#loading csv into pandas dataframe
df = pd.read_csv(csv_file_path)

df
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
# Checking if there are missing values
missing_values = df.isna() 
missing_values
# Out:
#        Unnamed: 0  genre_ids     id  original_language  original_title  \
# 0           False      False  False              False           False
# 1           False      False  False              False           False
# 2           False      False  False              False           False
# 3           False      False  False              False           False
# 4           False      False  False              False           False
# ...           ...        ...    ...                ...             ...
# 26512       False      False  False              False           False
# 26513       False      False  False              False           False
# 26514       False      False  False              False           False
# 26515       False      False  False              False           False
# 26516       False      False  False              False           False
#
#        popularity  release_date  title  vote_average  vote_count
# ...

# %%
# getting count of missing values
df.isna().sum()
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
#importing data visualsation library
import matplotlib.pyplot as plt

# %%
title =df['popularity']
title
# Out:
# 23811    80.773
# 11019    78.123
# 23812    60.534
# 11020    53.783
# 5179     50.289
#           ...
# 13879     0.600
# 13880     0.600
# 5029      0.600
# 13884     0.600
# 26516     0.600
# Name: popularity, Length: 26517, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 16))
plt.scatter(df['vote_count'], df['popularity'])
plt.title('Movies Popularity')
plt.xlabel('votes Count')
plt.ylabel('Popularity')
plt.show()
